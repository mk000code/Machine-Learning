# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

df = pd.read_excel("C:\\Users\\mdkai\\Downloads\\House Prices.csv (1).xlsx")


print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
x =df[["area"]]
y=df[["price"]]

print("X=",x.shape)
print("Y=",y.shape)

model = LinearRegression()
model.fit(x,y)  

print("Slope (weight): ",model.coef_)
print("Intercept (bias): ",model.intercept_)  

y_pred = model.predict(x)

print("Mean Absolute Error: ",mean_absolute_error(y,y_pred))
# Out:
# X= (545, 1)
# Y= (545, 1)
# Slope (weight):  [[461.97489427]]
# Intercept (bias):  [2387308.48239643]
# Mean Absolute Error:  1172305.5113148908

# %%
plt.scatter(x, y)
plt.plot(x, y_pred)

plt.xlabel("Area") 
plt.ylabel("Price")
plt.title("Sample Regression line Area vs Price")

plt.show()

# %%
df = pd.get_dummies(df,drop_first = True, dtype=int)

# %%
x=df.drop("price",axis=1)
y=df["price"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print("Mean Absolute Error: ",mean_absolute_error(y_test,y_pred))
r2=r2_score(y_test,y_pred)
print("R2 Score: ",r2)
# Out:
# Mean Absolute Error:  970043.403920164
# R2 Score:  0.6529242642153184
